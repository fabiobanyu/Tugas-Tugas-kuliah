# %%
import lightgbm as lgb
import joblib
import pandas as pd
import numpy as np
import os

# ==================================================================================
# UTILITY: TXT TO JOBLIB CONVERTER & HEALTH CHECK
# ==================================================================================

def convert_and_verify(txt_filename, joblib_filename):
    print(f"\n🔄 Memproses: {txt_filename} ...")
    
    # 1. CEK KEBERADAAN FILE
    if not os.path.exists(txt_filename):
        print(f"   ❌ SKIP: File '{txt_filename}' tidak ditemukan.")
        print("      (Pastikan dataset sudah di-add ke notebook ini)")
        return
    
    try:
        # 2. LOAD DARI TXT
        print("   📂 Loading TXT...")
        booster = lgb.Booster(model_file=txt_filename)
        
        # 3. SIMPAN KE JOBLIB
        print(f"   💾 Saving to {joblib_filename}...")
        joblib.dump(booster, joblib_filename)
        
        # 4. VERIFIKASI (RELOAD & PREDICT TEST)
        print("   🩺 Performing Health Check (Reload & Dummy Predict)...")
        
        # Reload dari joblib yang baru dibuat
        loaded_model = joblib.load(joblib_filename)
        
        # Buat Dummy Data (1 baris, jumlah fitur sesuai model)
        num_features = booster.num_feature()
        dummy_data = np.random.rand(1, num_features)
        
        # Coba Prediksi
        pred = loaded_model.predict(dummy_data)
        
        print(f"   ✅ SUKSES! Model sehat. Output probabilitas: {pred.shape}")
        print(f"   ✨ File siap: {joblib_filename}")
        
    except Exception as e:
        print(f"   ❌ ERROR saat konversi: {str(e)}")

# ==================================================================================
# DAFTAR MODEL (PATH DISESUAIKAN)
# ==================================================================================
files_to_convert = [
    # (Path Input dari Dataset Kaggle, Nama Output Joblib)
    ('/kaggle/input/model-v6-convert/model_final_v6.txt', 'model_final_v6.joblib')
]

print("🚀 MEMULAI KONVERSI MODEL V6 DARI INPUT...")

for txt_file, joblib_file in files_to_convert:
    convert_and_verify(txt_file, joblib_file)

print("\n🏁 SELESAI. Cek folder 'Output' di sebelah kanan untuk download file .joblib.")
# Out:
# 🚀 MEMULAI KONVERSI MODEL V6 DARI INPUT...
#
# 🔄 Memproses: /kaggle/input/model-v6-convert/model_final_v6.txt ...
#    📂 Loading TXT...
#    💾 Saving to model_final_v6.joblib...
#    🩺 Performing Health Check (Reload & Dummy Predict)...
#    ✅ SUKSES! Model sehat. Output probabilitas: (1, 5)
#    ✨ File siap: model_final_v6.joblib
#
# 🏁 SELESAI. Cek folder 'Output' di sebelah kanan untuk download file .joblib.
